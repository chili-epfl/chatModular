# %%
import numpy as np
import pandas as pd

# %%
forum_threads = pd.read_json('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/Forum Data/trip_advisor_threads_myscraping.json')
forum_subjects = pd.read_json('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/Forum Data/trip_advisor_myscraping.json')

# %%
forum_threads
# Out:
#                                                   Link  \
# 0    ShowTopic-g1-i12334-k7867029-See_TOP_QUESTIONS...
# 1    ShowTopic-g1-i12334-k7867029-See_TOP_QUESTIONS...
# 10   ShowTopic-g1-i12334-k8538588-Cox_and_Kings_tou...
# 100  ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
# 101  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 102  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 103  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 104  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 105  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 106  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 107  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 108  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 109  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 11   ShowTopic-g1-i12334-k8538588-Cox_and_Kings_tou...
# 110  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 111  ShowTopic-g1-i12334-k4899997-Record_Go_car_ren...
# 112  ShowTopic-g1-i12334-k9026823-Not_just_travel_h...
# 113  ShowTopic-g1-i12334-k9026823-Not_just_travel_h...
# 114  ShowTopic-g1-i12334-k9026823-Not_just_travel_h...
# 115  ShowTopic-g1-i12334-k9026823-Not_just_travel_h...
# 116  ShowTopic-g1-i12334-k9026823-Not_just_travel_h...
# 117  ShowTopic-g1-i12334-k9026823-Not_just_travel_h...
# 118  ShowTopic-g1-i12334-k9026823-Not_just_travel_h...
# 119  ShowTopic-g1-i12334-k9026823-Not_just_travel_h...
# 12   ShowTopic-g1-i12334-k8538588-Cox_and_Kings_tou...
# 120  ShowTopic-g1-i12334-k9026823-Not_just_travel_h...
# 121  ShowTopic-g1-i12334-k9026823-Not_just_travel_h...
# 122  ShowTopic-g1-i12334-k12139443-DO_NOT_USE_Agoda...
# 123  ShowTopic-g1-i12334-k12139443-DO_NOT_USE_Agoda...
# 124  ShowTopic-g1-i12334-k3505224-Travelsoon_com-Ho...
# ..                                                 ...
# 72   ShowTopic-g1-i12334-k7802525-Tours_through_Tri...
# 73   ShowTopic-g1-i12334-k7802525-Tours_through_Tri...
# 74   ShowTopic-g1-i12334-k7802525-Tours_through_Tri...
# 75   ShowTopic-g1-i12334-k7802525-Tours_through_Tri...
# 76   ShowTopic-g1-i12334-k7802525-Tours_through_Tri...
# 77   ShowTopic-g1-i12334-k7802525-Tours_through_Tri...
# 78   ShowTopic-g1-i12334-k7802525-Tours_through_Tri...
# 79   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 8    ShowTopic-g1-i12334-k5876122-How_to_Use_the_Ho...
# 80   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 81   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 82   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 83   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 84   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 85   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 86   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 87   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 88   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 89   ShowTopic-g1-i12334-k6582027-Homeaway_co_uk-Ho...
# 9    ShowTopic-g1-i12334-k5876122-How_to_Use_the_Ho...
# 90   ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
# 91   ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
# 92   ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
# 93   ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
# 94   ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
# 95   ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
# 96   ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
# 97   ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
# 98   ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
# 99   ShowTopic-g1-i12334-k5166741-Newmarket_Travel_...
#
#                                                Message  \
# 0                 HOW TO USE THE HOLIDAY TRAVEL FORUM!
# 1    Great advice BradJill.....any idea how to acce...
# 10   I am considering a conducted tour from Cox and...
# 100  I also did a xmas market tour with Newmarket t...
# 101  have just returned from a visit to the bulbfie...
# 102  We went on the spectacular bulb field trip, st...
# 103  Travelled with Newmarket for the Andre Rieu co...
# 104  Returned from Andrew Rieu Concert in Maastrich...
# 105  Recently use a car hire firm in Alicante Spain...
# 106  Unfortunately in Spain full to empty this is g...
# 107  I used RecordGO in Malaga in 2010 for a three ...
# 108  We booked a rental via ECONOMYCARRENTALS (Gree...
# 109            DO NOT EVER RENT FROM THESES COWBOYS!!!
# 11                                     Hello Shruti G,
# 110  Record Go? Rubbish and Renting pieces of junk....
# 111  We hired record car through DoYouSpain, Car br...
# 112  We had the most crap nissan note, dump, no cen...
# 113  I had rented car for two weeks with RecordGo. ...
# 114  Whole-heartedly agree with most of these. Wish...
# 115  just back from malaga where we rented a car wi...
# 116  Hi. Does anyone have any experience of booking...
# 117  I've never used this business nor encountered ...
# 118  I would be extremely cautious about using a co...
# 119             -:- Message from TripAdvisor staff -:-
# 12   For international travel, I don't recommend Co...
# 120  As you've said,Hays are a big independent trav...
# 121  They are a multi million pound company and abs...
# 122  Not Just Travel is a business in Bournemouth s...
# 123  Not Just Travel is a completely legitimate bus...
# 124  "Not Just Travel" is completely legit and the ...
# ..                                                 ...
# 72   Has anyone booked a trip through Trip a Deal a...
# 73   If you type the business name into the Search ...
# 74   Hi has anyone booked India and Nepal tour thro...
# 75     what is the statise of this company trip a deal
# 76                                         Hi laurene,
# 77   What i want to know is, is there anyone out th...
# 78                                   Hi again Laurene,
# 79   It seems people have used this company and has...
# 8                                   Good post Bradjill
# 80   I used them last year for Bali. Couldn't fault...
# 81   I have booked with them and I have had contact...
# 82                                   have a great trip
# 83   I have previously always used tripadvisor for ...
# 84                                      Hello bungley,
# 85                                          Hi bungley
# 86                              Villa Douceur De Vivre
# 87   This is the type of owner who IMHO is a total ...
# 88               Thank you for your help and comments.
# 89   Guess what homeaway.co.uk did not put up the c...
# 9                 Nicely done BradJill................
# 90                                         Hi bungley,
# 91   Something that no one has yet mentioned - I've...
# 92                                            Hi arty,
# 93   Write to the property owner, copy to Homeaway ...
# 94   Prior to Christmas we booked a Rhine Cruise/ C...
# 95                    Welcome to TripAdvisor, Phillip;
# 96   They didn't acknowledge the problem but did of...
# 97   Just returned from an horrendous journey with ...
# 98                    Seems should be avoided totally!
# 99   We have just returned from a Betwixtmas Rhine ...
#
#                                                  Title            Username
# 0                    See TOP QUESTIONS before posting!            BradJill
# 1                    See TOP QUESTIONS before posting!               Eden7
# 10                       Cox and Kings tours any good?            Shruti G
# 100              Newmarket Travel holidays beware!!!!!            GlynGail
# 101                               Record Go car rental              Diva04
# 102                               Record Go car rental           Shrimper3
# 103                               Record Go car rental            repleo52
# 104                               Record Go car rental          t/cBelfast
# 105                               Record Go car rental             David W
# 106                               Record Go car rental       Cliffeliamatt
# 107                               Record Go car rental              gelkel
# 108                               Record Go car rental            Janice13
# 109                               Record Go car rental            Temporar
# 11                       Cox and Kings tours any good?            BradJill
# 110                               Record Go car rental                Sn0d
# 111                               Record Go car rental        virginie1969
# 112  "Not just travel" - has anyone booked through ...               kjb66
# 113  "Not just travel" - has anyone booked through ...            BradJill
# 114  "Not just travel" - has anyone booked through ...            mcpinder
# 115  "Not just travel" - has anyone booked through ...           LeyLand10
# 116  "Not just travel" - has anyone booked through ...            madiwell
# 117  "Not just travel" - has anyone booked through ...           AlanBowen
# 118  "Not just travel" - has anyone booked through ...             Jalyn71
# 119  "Not just travel" - has anyone booked through ...        lloydhankins
# 12                       Cox and Kings tours any good?            Roshni K
# 120  "Not just travel" - has anyone booked through ...             WENDY M
# 121  "Not just travel" - has anyone booked through ...            geoffpfc
# 122         DO NOT USE : Agoda.com Online booking site            CostaL99
# 123         DO NOT USE : Agoda.com Online booking site             KVE1005
# 124                                     travelsoon.com               strus
# ..                                                 ...                 ...
# 72                           Tours through Trip a Deal           Avanti_SG
# 73                           Tours through Trip a Deal           laurene p
# 74                           Tours through Trip a Deal           Avanti_SG
# 75                           Tours through Trip a Deal      bwisetraveller
# 76                           Tours through Trip a Deal          Anita12014
# 77                           Tours through Trip a Deal      bwisetraveller
# 78                           Tours through Trip a Deal          Anita12014
# 79                                      Homeaway.co.uk             Bungley
# 8                  How to Use the Holiday Travel Forum        thegoodwitch
# 80                                      Homeaway.co.uk            BradJill
# 81                                      Homeaway.co.uk             Steve B
# 82                                      Homeaway.co.uk             Bungley
# 83                                      Homeaway.co.uk             Steve B
# 84                                      Homeaway.co.uk             Bungley
# 85                                      Homeaway.co.uk             Bungley
# 86                                      Homeaway.co.uk             KVE1005
# 87                                      Homeaway.co.uk              Arty T
# 88                                      Homeaway.co.uk             KVE1005
# 89                                      Homeaway.co.uk             fillyme
# 9                  How to Use the Holiday Travel Forum               Eden7
# 90               Newmarket Travel holidays beware!!!!!          philipg946
# 91               Newmarket Travel holidays beware!!!!!          RescueTeam
# 92               Newmarket Travel holidays beware!!!!!          philipg946
# 93               Newmarket Travel holidays beware!!!!!       mikeWalesU_k_
# 94               Newmarket Travel holidays beware!!!!!            Rhythm D
# 95               Newmarket Travel holidays beware!!!!!     gardenofengland
# 96               Newmarket Travel holidays beware!!!!!      oscar01Suffolk
# 97               Newmarket Travel holidays beware!!!!!  patSouthernEngland
# 98               Newmarket Travel holidays beware!!!!!       Coffee_cup127
# 99               Newmarket Travel holidays beware!!!!!            Audrey L
#
# [156 rows x 4 columns]

# %%
forum_threads.Message = forum_threads.Message.apply(lambda msg: msg.split('_________________')[0])
forum_subjects = forum_subjects.drop_duplicates(subset=['Link'], keep='first')
forum_threads = forum_threads.drop_duplicates(subset=['Link', 'Message'], keep='first')
forum_threads.to_json('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/Forum Data/forum_threads_ta.json')
forum_subjects.to_json('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/Forum Data/forum_subjects_ta.json')

# %% [markdown]
# The total number of posts is:

# %%
len(forum_threads)
# Out:
# 153

# %% [markdown]
# The total number of threads is:

# %%
len(forum_subjects)
# Out:
# 20

# %%
def is_question(sentence):
    """
    Returns true if a sentence is a question.
    :param sentence: list of strings, the sentence is tokenized
    :return: boolean
    """
    new_sentence = (''.join([c for c in sentence if c.isalnum() or c in '?!./ "\''])).replace('/', ' ')
    #print(new_sentence)
    tokens = nltk.word_tokenize(new_sentence)
    tokens = [word[:1].lower() + word[1:] for word in tokens]
    try:
        question_mark_index = tokens.index('?')
        #before was in next if but failed
        tags = nltk.pos_tag(tokens[:question_mark_index + 1])
        if question_mark_index == len(tokens) - 1:
            #tags = nltk.pos_tag(tokens[:question_mark_index + 1])
            if tags[0][1] in 'MD VB VBD VBN VBP VBZ WRB WP WDT'.split(' ') and tags[0][0] not in 'am'.split(' '):
                for tag in tags:
                    if tag[1].startswith('VB'):
                        return True
    except:
        pass
    return False

# %%
filtered_forum_subjects = forum_subjects[forum_subjects['Title'].map(lambda x: is_question(x))]
len(filtered_forum_subjects)
# Out:
# 1

# %%
filtered_forum_subjects.head()
# Out:
#                                                 Link  \
# 9  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
#
#                             Title
# 9  Can We Trust Agoda.com Review?

# %% [markdown]
# Is this cell really useful?

# %%
merged_forum_threads = pd.merge(forum_threads.drop(['Title'], axis=1), forum_subjects, 
                                on='Link', how='inner')
merged_forum_threads.to_json('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/Forum Data/merged_forum_threads_ta.json')
merged_forum_threads.head()
# Out:
#                                                 Link  \
# 0  ShowTopic-g1-i12334-k7867029-See_TOP_QUESTIONS...
# 1  ShowTopic-g1-i12334-k7867029-See_TOP_QUESTIONS...
# 2  ShowTopic-g1-i12334-k7867029-See_TOP_QUESTIONS...
# 3  ShowTopic-g1-i12334-k8538588-Cox_and_Kings_tou...
# 4  ShowTopic-g1-i12334-k8538588-Cox_and_Kings_tou...
#
#                                              Message  Username  \
# 0               HOW TO USE THE HOLIDAY TRAVEL FORUM!  BradJill
# 1  Great advice BradJill.....any idea how to acce...     Eden7
# 2  Now that is a good question. I know this is mu...  BradJill
# 3  I am considering a conducted tour from Cox and...  Shruti G
# 4                                    Hello Shruti G,  BradJill
#
#                                Title
# 0  See TOP QUESTIONS before posting!
# 1  See TOP QUESTIONS before posting!
# 2  See TOP QUESTIONS before posting!
# 3      Cox and Kings tours any good?
# 4      Cox and Kings tours any good?

# %%
len(merged_forum_threads)
# Out:
# 153

# %% [markdown]
# ## For All Collected Data

# %%
import nltk.data
import subprocess
import pandas as pd

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
df = pd.read_json('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/Forum Data/merged_forum_threads_ta.json')
df.head()
df = df[df['Message'].map(lambda x: x is not None)]  #check if useful for other sites than TripAdvisor

# %%
titles_with_first_post = df.groupby('Link').first().reset_index()[['Link', 'Title', 'Username', 'Message']]
titles_with_first_post.columns = ['Link', 'Title', 'Seeker', 'First_Post']
titles_with_first_post.head()
# Out:
#                                                 Link  \
# 0  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 1  ShowTopic-g1-i12334-k10535749-Complaint_about_...
# 2  ShowTopic-g1-i12334-k12137440-First_Choice_poo...
# 3  ShowTopic-g1-i12334-k12138458-Fraudulent_websi...
# 4  ShowTopic-g1-i12334-k12139443-DO_NOT_USE_Agoda...
#
#                                              Title               Seeker  \
# 0                   Can We Trust Agoda.com Review?         Alvy_Advisor
# 1                    complaint about www.yatra.com             Nilesh T
# 2                  First Choice poor customer care               Roylps
# 3  Fraudulent website/domain posing as TripAdvisor  Navigate50787218737
# 4       DO NOT USE : Agoda.com Online booking site             CostaL99
#
#                                           First_Post
# 0  I have never written a review however I feel s...
# 1             -:- Message from TripAdvisor staff -:-
# 2  Hello Komi101! The trip was great. We just got...
# 3  Anyone experience unresolved problems with Fir...
# 4  Not Just Travel is a business in Bournemouth s...

# %%
def tokenize_properly(text):
    if text is not None:
        r = [sent for sent in tokenizer.tokenize(text.replace('\n', '. ')) 
            if len(sent.replace('.', '').replace(' ', '')) >= 2]
        return r

titles_with_first_post.Title = titles_with_first_post.Title.apply(tokenize_properly)
titles_with_first_post.First_Post = titles_with_first_post.First_Post.apply(tokenize_properly)
titles_with_first_post.head()
# Out:
#                                                 Link  \
# 0  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 1  ShowTopic-g1-i12334-k10535749-Complaint_about_...
# 2  ShowTopic-g1-i12334-k12137440-First_Choice_poo...
# 3  ShowTopic-g1-i12334-k12138458-Fraudulent_websi...
# 4  ShowTopic-g1-i12334-k12139443-DO_NOT_USE_Agoda...
#
#                                                Title               Seeker  \
# 0                   [Can We Trust Agoda.com Review?]         Alvy_Advisor
# 1                    [complaint about www.yatra.com]             Nilesh T
# 2                  [First Choice poor customer care]               Roylps
# 3  [Fraudulent website/domain posing as TripAdvisor]  Navigate50787218737
# 4       [DO NOT USE : Agoda.com Online booking site]             CostaL99
#
#                                           First_Post
# 0  [I have never written a review however I feel ...
# 1           [-:- Message from TripAdvisor staff -:-]
# 2  [Hello Komi101!, The trip was great., We just ...
# 3  [Anyone experience unresolved problems with Fi...
# 4  [Not Just Travel is a business in Bournemouth ...

# %%
titles_with_first_post['Title_sent_count'] = titles_with_first_post.Title.apply(len)
titles_with_first_post['FP_sent_count'] = titles_with_first_post.First_Post.apply(len)
titles_with_first_post.head()
# Out:
#                                                 Link  \
# 0  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 1  ShowTopic-g1-i12334-k10535749-Complaint_about_...
# 2  ShowTopic-g1-i12334-k12137440-First_Choice_poo...
# 3  ShowTopic-g1-i12334-k12138458-Fraudulent_websi...
# 4  ShowTopic-g1-i12334-k12139443-DO_NOT_USE_Agoda...
#
#                                                Title               Seeker  \
# 0                   [Can We Trust Agoda.com Review?]         Alvy_Advisor
# 1                    [complaint about www.yatra.com]             Nilesh T
# 2                  [First Choice poor customer care]               Roylps
# 3  [Fraudulent website/domain posing as TripAdvisor]  Navigate50787218737
# 4       [DO NOT USE : Agoda.com Online booking site]             CostaL99
#
#                                           First_Post  Title_sent_count  \
# 0  [I have never written a review however I feel ...                 1
# 1           [-:- Message from TripAdvisor staff -:-]                 1
# 2  [Hello Komi101!, The trip was great., We just ...                 1
# 3  [Anyone experience unresolved problems with Fi...                 1
# 4  [Not Just Travel is a business in Bournemouth ...                 1
#
#    FP_sent_count
# 0              2
# 1              1
# 2             10
# 3              1
# 4              4

# %%
titles_with_messages = pd.merge(titles_with_first_post, 
                                df[['Username', 'Message', 'Link']], on='Link')
titles_with_messages.rename(columns={'Username':'Replier'}, inplace=True)
titles_with_messages = titles_with_messages[titles_with_messages.apply(
    lambda row: not row['First_Post'] == row['Message'] and not row['Seeker'] == row['Replier'], axis=1)]
titles_with_messages.Message = titles_with_messages.Message.apply(tokenize_properly)
titles_with_messages.rename(columns={'Message': 'Reply'}, inplace=True)
titles_with_messages['Reply_sent_count'] = titles_with_messages.Reply.apply(len)
titles_with_messages.head()
# Out:
#                                                 Link  \
# 1  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 2  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 3  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 4  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 5  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
#
#                               Title        Seeker  \
# 1  [Can We Trust Agoda.com Review?]  Alvy_Advisor
# 2  [Can We Trust Agoda.com Review?]  Alvy_Advisor
# 3  [Can We Trust Agoda.com Review?]  Alvy_Advisor
# 4  [Can We Trust Agoda.com Review?]  Alvy_Advisor
# 5  [Can We Trust Agoda.com Review?]  Alvy_Advisor
#
#                                           First_Post  Title_sent_count  \
# 1  [I have never written a review however I feel ...                 1
# 2  [I have never written a review however I feel ...                 1
# 3  [I have never written a review however I feel ...                 1
# 4  [I have never written a review however I feel ...                 1
# 5  [I have never written a review however I feel ...                 1
#
#    FP_sent_count      Replier  \
# 1              2       Toopaz
# 2              2       Jill M
# 3              2     RojBlake
# 4              2  travelkat88
# 5              2    Avanti_SG
#
#                                                Reply  Reply_sent_count
# 1  [I’ve only ever booked flights on Qantas, doin...                 4
# 2  [I’m not privy to the conversation which took ...                 2
# 3                                         [Hi Guys,]                 1
# 4               [Hi Alvy and welcome to the forums.]                 1
# 5  [The one thing that's better about reviews in ...                 3

# %%
titles_with_messages.columns
# Out:
# Index(['Link', 'Title', 'Seeker', 'First_Post', 'Title_sent_count',
#        'FP_sent_count', 'Replier', 'Reply', 'Reply_sent_count'],
#       dtype='object')

# %%
len(titles_with_messages)
# Out:
# 120

# %%
CHOSEN_COLUMNS = ['Link', 'Reply']
titles_with_messages[CHOSEN_COLUMNS].head()
# Out:
#                                                 Link  \
# 1  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 2  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 3  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 4  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 5  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
#
#                                                Reply
# 1  [I’ve only ever booked flights on Qantas, doin...
# 2  [I’m not privy to the conversation which took ...
# 3                                         [Hi Guys,]
# 4               [Hi Alvy and welcome to the forums.]
# 5  [The one thing that's better about reviews in ...

# %%
msg_df = titles_with_messages[CHOSEN_COLUMNS]
msg_df.head()
# Out:
#                                                 Link  \
# 1  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 2  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 3  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 4  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 5  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
#
#                                                Reply
# 1  [I’ve only ever booked flights on Qantas, doin...
# 2  [I’m not privy to the conversation which took ...
# 3                                         [Hi Guys,]
# 4               [Hi Alvy and welcome to the forums.]
# 5  [The one thing that's better about reviews in ...

# %%
titles_with_first_post.head()
# Out:
#                                                 Link  \
# 0  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 1  ShowTopic-g1-i12334-k10535749-Complaint_about_...
# 2  ShowTopic-g1-i12334-k12137440-First_Choice_poo...
# 3  ShowTopic-g1-i12334-k12138458-Fraudulent_websi...
# 4  ShowTopic-g1-i12334-k12139443-DO_NOT_USE_Agoda...
#
#                                                Title               Seeker  \
# 0                   [Can We Trust Agoda.com Review?]         Alvy_Advisor
# 1                    [complaint about www.yatra.com]             Nilesh T
# 2                  [First Choice poor customer care]               Roylps
# 3  [Fraudulent website/domain posing as TripAdvisor]  Navigate50787218737
# 4       [DO NOT USE : Agoda.com Online booking site]             CostaL99
#
#                                           First_Post  Title_sent_count  \
# 0  [I have never written a review however I feel ...                 1
# 1           [-:- Message from TripAdvisor staff -:-]                 1
# 2  [Hello Komi101!, The trip was great., We just ...                 1
# 3  [Anyone experience unresolved problems with Fi...                 1
# 4  [Not Just Travel is a business in Bournemouth ...                 1
#
#    FP_sent_count
# 0              2
# 1              1
# 2             10
# 3              1
# 4              4

# %%
tfp_df = titles_with_first_post[['Link', 'Title', 'First_Post']]
tfp_df.head()
# Out:
#                                                 Link  \
# 0  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 1  ShowTopic-g1-i12334-k10535749-Complaint_about_...
# 2  ShowTopic-g1-i12334-k12137440-First_Choice_poo...
# 3  ShowTopic-g1-i12334-k12138458-Fraudulent_websi...
# 4  ShowTopic-g1-i12334-k12139443-DO_NOT_USE_Agoda...
#
#                                                Title  \
# 0                   [Can We Trust Agoda.com Review?]
# 1                    [complaint about www.yatra.com]
# 2                  [First Choice poor customer care]
# 3  [Fraudulent website/domain posing as TripAdvisor]
# 4       [DO NOT USE : Agoda.com Online booking site]
#
#                                           First_Post
# 0  [I have never written a review however I feel ...
# 1           [-:- Message from TripAdvisor staff -:-]
# 2  [Hello Komi101!, The trip was great., We just ...
# 3  [Anyone experience unresolved problems with Fi...
# 4  [Not Just Travel is a business in Bournemouth ...

# %% [markdown]
# ## Precomputing word2vec

# %%
import gensim
model = gensim.models.KeyedVectors.load_word2vec_format('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/Forum Data/GoogleNews-vectors-negative300.bin', binary=True)
from nltk.corpus import stopwords
stopwords = set(nltk.corpus.stopwords.words('english'))

def get_sentence_vector(sentence):
    tokens = [token for token in nltk.word_tokenize(sentence) if token not in stopwords]
    vectors = []
    for token in tokens:
        try:
            word_vec = model.wv[token]
            vectors.append(word_vec)
        except:
            pass
    if vectors:
        return np.mean(vectors, axis=0)
    else:
        return []

# %%
tfp_df['Title_word2vec'] = tfp_df.Title.apply(lambda sents: [get_sentence_vector(sent) for sent in sents])
tfp_df['First_Post_word2vec'] = tfp_df.First_Post.apply(lambda sents: [get_sentence_vector(sent) for sent in sents])
tfp_df.head()
# Out:
# C:\Users\Meret\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Meret\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Meret\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                 Link  \
# 0  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 1  ShowTopic-g1-i12334-k10535749-Complaint_about_...
# 2  ShowTopic-g1-i12334-k12137440-First_Choice_poo...
# 3  ShowTopic-g1-i12334-k12138458-Fraudulent_websi...
# 4  ShowTopic-g1-i12334-k12139443-DO_NOT_USE_Agoda...
#
#                                                Title  \
# 0                   [Can We Trust Agoda.com Review?]
# 1                    [complaint about www.yatra.com]
# 2                  [First Choice poor customer care]
# 3  [Fraudulent website/domain posing as TripAdvisor]
# 4       [DO NOT USE : Agoda.com Online booking site]
#
#                                           First_Post  \
# 0  [I have never written a review however I feel ...
# 1           [-:- Message from TripAdvisor staff -:-]
# 2  [Hello Komi101!, The trip was great., We just ...
# 3  [Anyone experience unresolved problems with Fi...
# 4  [Not Just Travel is a business in Bournemouth ...
#
#                                       Title_word2vec  \
# 0  [[0.013427734, 0.031591795, -0.0045898436, 0.0...
# 1  [[-0.11621094, 0.023925781, 0.0067443848, -0.3...
# 2  [[-0.02890625, 0.12822266, -0.0077636717, 0.06...
# 3  [[0.0758667, 0.0509847, -0.07029215, -0.111226...
# 4  [[-0.0015869141, -0.117885046, -0.011247908, 0...
#
#                                  First_Post_word2vec
# 0  [[-0.02116148, 0.023279497, -0.016314846, 0.04...
# 1  [[0.008158366, -0.036699932, -0.032043457, 0.0...
# 2  [[-0.05102539, 0.12060547, -0.012573242, 0.030...
# 3  [[0.11002023, 0.056989398, -0.037336078, 0.043...
# 4  [[0.09638468, 0.05519994, -0.03358968, 0.08068...

# %%
msg_df['Reply_word2vec'] = msg_df.Reply.apply(lambda sents: [get_sentence_vector(sent) for sent in sents])
msg_df.head()
# Out:
# C:\Users\Meret\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Meret\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                                 Link  \
# 1  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 2  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 3  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 4  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 5  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
#
#                                                Reply  \
# 1  [I’ve only ever booked flights on Qantas, doin...
# 2  [I’m not privy to the conversation which took ...
# 3                                         [Hi Guys,]
# 4               [Hi Alvy and welcome to the forums.]
# 5  [The one thing that's better about reviews in ...
#
#                                       Reply_word2vec
# 1  [[0.022592163, -0.055532835, -0.049853515, -0....
# 2  [[0.035095215, 0.025489807, 0.032470703, -0.03...
# 3  [[-0.07519531, -0.0026855469, 0.03125, 0.17541...
# 4  [[-0.07525635, 0.03955078, 0.07043457, -0.0397...
# 5  [[-0.04130249, 0.049718477, -0.021977996, 0.07...

# %%
import pickle

# write python dict to a file
output1 = open('tfp_df_COPY_ta.pkl', 'wb')
pickle.dump(tfp_df, output1)

output2 = open('msg_df_COPY_ta.pkl', 'wb')
pickle.dump(msg_df, output2)

# %% [markdown]
# ## Dot Product Similarity Functions

# %%
import pandas as pd
from os import listdir
import gensim
import numpy as np
import nltk
from nltk.corpus import stopwords
import ast
stopwords = set(nltk.corpus.stopwords.words('english'))

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/Forum Data/GoogleNews-vectors-negative300.bin', binary=True)

# %%
tfp_df = pd.read_pickle('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/tfp_df_COPY_ta.pkl')
tfp_df.head()
# Out:
#                                                 Link  \
# 0  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 1  ShowTopic-g1-i12334-k10535749-Complaint_about_...
# 2  ShowTopic-g1-i12334-k12137440-First_Choice_poo...
# 3  ShowTopic-g1-i12334-k12138458-Fraudulent_websi...
# 4  ShowTopic-g1-i12334-k12139443-DO_NOT_USE_Agoda...
#
#                                                Title  \
# 0                   [Can We Trust Agoda.com Review?]
# 1                    [complaint about www.yatra.com]
# 2                  [First Choice poor customer care]
# 3  [Fraudulent website/domain posing as TripAdvisor]
# 4       [DO NOT USE : Agoda.com Online booking site]
#
#                                           First_Post  \
# 0  [I have never written a review however I feel ...
# 1           [-:- Message from TripAdvisor staff -:-]
# 2  [Hello Komi101!, The trip was great., We just ...
# 3  [Anyone experience unresolved problems with Fi...
# 4  [Not Just Travel is a business in Bournemouth ...
#
#                                       Title_word2vec  \
# 0  [[0.013427734, 0.031591795, -0.0045898436, 0.0...
# 1  [[-0.11621094, 0.023925781, 0.0067443848, -0.3...
# 2  [[-0.02890625, 0.12822266, -0.0077636717, 0.06...
# 3  [[0.0758667, 0.0509847, -0.07029215, -0.111226...
# 4  [[-0.0015869141, -0.117885046, -0.011247908, 0...
#
#                                  First_Post_word2vec
# 0  [[-0.02116148, 0.023279497, -0.016314846, 0.04...
# 1  [[0.008158366, -0.036699932, -0.032043457, 0.0...
# 2  [[-0.05102539, 0.12060547, -0.012573242, 0.030...
# 3  [[0.11002023, 0.056989398, -0.037336078, 0.043...
# 4  [[0.09638468, 0.05519994, -0.03358968, 0.08068...

# %%
msg_df = pd.read_pickle('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/msg_df_COPY_ta.pkl')
msg_df.head()
# Out:
#                                                 Link  \
# 1  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 2  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 3  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 4  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
# 5  ShowTopic-g1-i12334-k10319402-Can_We_Trust_Ago...
#
#                                                Reply  \
# 1  [I’ve only ever booked flights on Qantas, doin...
# 2  [I’m not privy to the conversation which took ...
# 3                                         [Hi Guys,]
# 4               [Hi Alvy and welcome to the forums.]
# 5  [The one thing that's better about reviews in ...
#
#                                       Reply_word2vec
# 1  [[0.022592163, -0.055532835, -0.049853515, -0....
# 2  [[0.035095215, 0.025489807, 0.032470703, -0.03...
# 3  [[-0.07519531, -0.0026855469, 0.03125, 0.17541...
# 4  [[-0.07525635, 0.03955078, 0.07043457, -0.0397...
# 5  [[-0.04130249, 0.049718477, -0.021977996, 0.07...

# %%
def cosine_similarity(vec1, vec2):
    return np.dot(vec1, vec2)/(np.linalg.norm(vec1) * np.linalg.norm(vec2))

def get_sentence_vector(sentence):
    tokens = [token for token in nltk.word_tokenize(sentence) if token not in stopwords]
    vectors = []
    for token in tokens:
        try:
            word_vec = model.wv[token]
            vectors.append(word_vec)
        except:
            pass
    if vectors:
        return np.mean(vectors, axis=0)
    else:
        return []

def is_not_null(sent_vec):
    for element in sent_vec:
        if not element == 0.0:
            return True
    return False

def sent_to_text_similarity(sent_vec, text_vec):
    similarities = []
    for vec in text_vec:
        if is_not_null(vec):
            similarities.append(np.dot(sent_vec, vec)/(np.linalg.norm(sent_vec) * np.linalg.norm(vec)))
    if similarities:
        return np.mean(similarities)
    else:
        return np.nan

def text_to_text_similarity(sent_vecs1, sent_vecs2):
    similarities = []
    for v1 in sent_vecs1:
        if is_not_null(v1):
            similarity = sent_to_text_similarity(v1, sent_vecs2)
            if not np.isnan(similarity):
                similarities.append(similarity)
    if similarities:
        return np.mean(similarities)
    else:
        return np.nan

def text_to_corpus_similarity(text, corpus):
    sent_vecs = text_to_sent_vec(text)
    corpus_vecs = [text_to_sent_vec(other_text) for other_text in corpus]
    max_sim = 0
    index = -1
    for text_index in range(len(corpus_vecs)):
        similarity = text_to_text_similarity(sent_vecs, corpus_vecs[text_index])
        if not np.isnan(similarity) and max_sim < similarity:
            max_sim = similarity
            index = text_index
    if index >= 0:
        return corpus[index]
    else:
        return None

# %% [markdown]
# ## Chatbot Functions

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
def compute_similarity(row, sent_vec):
    title_sim = 0
    title_word2vec = row['Title_word2vec']
    if len(title_word2vec) > 0:
        if len(title_word2vec[0]) > 0:
            title_sim = cosine_similarity(sent_vec, title_word2vec[0])
    return title_sim

def compute_separate_similarity(row, sent_vecs):
    title_sim = 0
    title_word2vec = row['Title_word2vec']
    if len(title_word2vec) > 0:
        if len(title_word2vec[0]) > 0:
            title_sim = np.dot(sent_vecs[0], title_word2vec[0])/(np.linalg.norm(sent_vecs[0])*np.linalg.norm(title_word2vec[0]))
    fp_sim = text_to_text_similarity(sent_vecs[1:], row['First_Post_word2vec'])
    return title_sim + fp_sim

def compute_separate_similarity_no_question(row, sent_vecs):
    fp_sim = text_to_text_similarity(sent_vecs, row['First_Post_word2vec'])
    return fp_sim

def get_most_similar_title(sentences, sent_vecs):
    if sentences == 0:
        raise ValueError('Write something!')
    elif len(sentences) == 1:
        title_fp_sim = tfp_df.apply(lambda row: compute_similarity(row, sent_vecs[0]), axis=1)
    elif sentences[0].endswith('?'):
        title_fp_sim = tfp_df.apply(lambda row: compute_separate_similarity(row, sent_vecs), axis=1)
    else:
        title_fp_sim = tfp_df.apply(lambda row: compute_separate_similarity_no_question(row, sent_vecs), axis=1)
    return tfp_df.loc[title_fp_sim.idxmax()]

def get_response_sentences(sentences, sent_vecs, link, max_sentences):
    answer_df = pd.read_pickle('C:/Users/Meret/Documents/EPFL/3Annee/Semestre_5/Projet/Forum_Chatbot/msg_df_COPY_ht.pkl')
    answer_df = answer_df[answer_df['Link'].map(lambda x: x == link)]
    if answer_df.empty:
        s = 'I did not find a matching sentence'
        return s
    
    best_answer = answer_df.loc[answer_df['Reply_word2vec'].apply(lambda other_vecs: 
                                                     text_to_text_similarity(sent_vecs, other_vecs)).idxmax()]
    
    best_sentence_idx = np.argmax([sent_to_text_similarity(sent_vec, sent_vecs) for sent_vec in best_answer.Reply_word2vec if len(sent_vec)])
    reply_sentences = best_answer.Reply
    if max_sentences <= 1:
        return reply_sentences[best_sentence_idx]
    else:
        context_sent_count = int((max_sentences - 1)/2)
        sent_count = len(reply_sentences)
        lower_bound = best_sentence_idx - context_sent_count
        upper_bound = best_sentence_idx + context_sent_count + 1
        return ' '.join(reply_sentences[max(0, lower_bound - max(0, upper_bound - sent_count)): 
                                        min(upper_bound + max(0, 0 - lower_bound) + ((max_sentences - 1) % 2), sent_count)])

def chatbot_answer(question, max_sentences=1):
    sentences = tokenizer.tokenize(question)
    sent_vecs = [get_sentence_vector(sent) for sent in sentences]
    most_similar_title = get_most_similar_title(sentences, sent_vecs)
    return get_response_sentences(sentences, sent_vecs, most_similar_title.Link, max_sentences)

# %%
chatbot_answer("Moma", max_sentences=2)
# Out:
# C:\Users\Meret\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   if __name__ == '__main__':
# 'Hi again Laurene,'
